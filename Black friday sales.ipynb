# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (550068, 12)

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
train.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
train.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
test.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
data = pd.concat([train,test],axis=0,join='outer')

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# 1                               2               0                   1
# 2                               2               0                  12
# 3                               2               0                  12
# 4                              4+               0                   8
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                      NaN                 NaN    8370.0
# 1                      6.0                14.0   15200.0
# 2                      NaN                 NaN    1422.0
# 3                     14.0                 NaN    1057.0
# 4                      NaN                 NaN    7969.0
# ...                    ...                 ...       ...
# 233594                 NaN                 NaN       NaN
# 233595                 8.0                 NaN       NaN
# 233596                 5.0                12.0       NaN
# 233597                16.0                 NaN       NaN
# 233598                 5.0                 NaN       NaN
#
# [783667 rows x 12 columns]

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# dtype: int64

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
data['Product_Category_2'].fillna(0,inplace=True)
data['Product_Category_3'].fillna(0,inplace=True)

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# dtype: int64

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
#data.drop(columns=['User_ID','Product_ID'],inplace=True)
map_userid = data['User_ID'].value_counts()/len(data['User_ID'])
data['User_ID'] = data['User_ID'].map(map_userid)

# %%
map_userid = data['Product_ID'].value_counts()/len(data['Product_ID'])
data['Product_ID'] = data['Product_ID'].map(map_userid)

# %%
data.head()
# Out:
#     User_ID  Product_ID Gender   Age  Occupation City_Category  \
# 0  0.000060    0.000439      F  0-17          10             A
# 1  0.000060    0.001078      F  0-17          10             A
# 2  0.000060    0.000191      F  0-17          10             A
# 3  0.000060    0.000633      F  0-17          10             A
# 4  0.000137    0.000361      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
data.head()
# Out:
#     User_ID  Product_ID Gender   Age  Occupation City_Category  \
# 0  0.000060    0.000439      F  0-17          10             A
# 1  0.000060    0.001078      F  0-17          10             A
# 2  0.000060    0.000191      F  0-17          10             A
# 3  0.000060    0.000633      F  0-17          10             A
# 4  0.000137    0.000361      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
#plt.figure(figsize=(10,7))
for i in data.columns:
    plt.figure(figsize=(10,5))
    if i != 'Purchase':
        sns.countplot(data[i])
        plt.show()

# %%
for i in data.columns:
    plt.figure(figsize=(10,5))
    if i != 'Purchase':
        data.groupby(by=[i])['Purchase'].mean().plot(kind='bar')
        plt.show()

# %% [markdown]
# ## Categorical treatment

# %%
data.dtypes
# Out:
# User_ID                       float64
# Product_ID                    float64
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# dtype: object

# %%
data.head()
# Out:
#     User_ID  Product_ID Gender   Age  Occupation City_Category  \
# 0  0.000060    0.000439      F  0-17          10             A
# 1  0.000060    0.001078      F  0-17          10             A
# 2  0.000060    0.000191      F  0-17          10             A
# 3  0.000060    0.000633      F  0-17          10             A
# 4  0.000137    0.000361      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
data['Gender'] = pd.get_dummies(data['Gender'],drop_first=True)

# %%
data.head()
# Out:
#     User_ID  Product_ID  Gender   Age  Occupation City_Category  \
# 0  0.000060    0.000439       0  0-17          10             A
# 1  0.000060    0.001078       0  0-17          10             A
# 2  0.000060    0.000191       0  0-17          10             A
# 3  0.000060    0.000633       0  0-17          10             A
# 4  0.000137    0.000361       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['Age'].value_counts()
# Out:
# 26-35    313015
# 36-45    156724
# 18-25    141953
# 46-50     65278
# 51-55     54784
# 55+       30579
# 0-17      21334
# Name: Age, dtype: int64

# %%
data['Age'] = le.fit_transform(data['Age'])

# %%
data.head()
# Out:
#     User_ID  Product_ID  Gender  Age  Occupation City_Category  \
# 0  0.000060    0.000439       0    0          10             A
# 1  0.000060    0.001078       0    0          10             A
# 2  0.000060    0.000191       0    0          10             A
# 3  0.000060    0.000633       0    0          10             A
# 4  0.000137    0.000361       1    6          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
data['Stay_In_Current_City_Years'] = le.fit_transform(data['Stay_In_Current_City_Years'])

# %%
data.head()
# Out:
#     User_ID  Product_ID  Gender  Age  Occupation City_Category  \
# 0  0.000060    0.000439       0    0          10             A
# 1  0.000060    0.001078       0    0          10             A
# 2  0.000060    0.000191       0    0          10             A
# 3  0.000060    0.000633       0    0          10             A
# 4  0.000137    0.000361       1    6          16             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 0.0                 0.0    8370.0
# 1                 6.0                14.0   15200.0
# 2                 0.0                 0.0    1422.0
# 3                14.0                 0.0    1057.0
# 4                 0.0                 0.0    7969.0

# %%
data = pd.get_dummies(data,drop_first=True)

# %%
data.head()
# Out:
#     User_ID  Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  0.000060    0.000439       0    0          10                           2
# 1  0.000060    0.001078       0    0          10                           2
# 2  0.000060    0.000191       0    0          10                           2
# 3  0.000060    0.000633       0    0          10                           2
# 4  0.000137    0.000361       1    6          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 0.0                 0.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 0.0                 0.0
# 3               0                  12                14.0                 0.0
# 4               0                   8                 0.0                 0.0
#
#    Purchase  City_Category_B  City_Category_C
# 0    8370.0                0                0
# 1   15200.0                0                0
# 2    1422.0                0                0
# 3    1057.0                0                0
# 4    7969.0                0                1

# %%
data.dtypes
# Out:
# User_ID                       float64
# Product_ID                    float64
# Gender                          uint8
# Age                             int32
# Occupation                      int64
# Stay_In_Current_City_Years      int32
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# City_Category_B                 uint8
# City_Category_C                 uint8
# dtype: object

# %%
train_f = data[~(data['Purchase'].isnull())]

# %%
test_f = data[data['Purchase'].isnull()]

# %%
train_f.head()
# Out:
#     User_ID  Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  0.000060    0.000439       0    0          10                           2
# 1  0.000060    0.001078       0    0          10                           2
# 2  0.000060    0.000191       0    0          10                           2
# 3  0.000060    0.000633       0    0          10                           2
# 4  0.000137    0.000361       1    6          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 0.0                 0.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 0.0                 0.0
# 3               0                  12                14.0                 0.0
# 4               0                   8                 0.0                 0.0
#
#    Purchase  City_Category_B  City_Category_C
# 0    8370.0                0                0
# 1   15200.0                0                0
# 2    1422.0                0                0
# 3    1057.0                0                0
# 4    7969.0                0                1

# %%
del test_f['Purchase']

# %%
test_f.head()
# Out:
#     User_ID  Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  0.000019    0.001701       1    4           7                           2
# 1  0.000108    0.000473       1    2          17                           0
# 2  0.000413    0.000277       0    3           1                           4
# 3  0.000413    0.000029       0    3           1                           4
# 4  0.000140    0.000997       0    2           1                           1
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               1                   1                11.0                 0.0
# 1               0                   3                 5.0                 0.0
# 2               1                   5                14.0                 0.0
# 3               1                   4                 9.0                 0.0
# 4               0                   4                 5.0                12.0
#
#    City_Category_B  City_Category_C
# 0                1                0
# 1                0                1
# 2                1                0
# 3                1                0
# 4                0                1

# %% [markdown]
# ## Train test split

# %%
x = train_f.drop(columns=['Purchase'])
y = train_f['Purchase']

# %%
import statsmodels.api as sm

# %%
X = sm.add_constant(x)

# %%
X.head()
# Out:
#    const   User_ID  Product_ID  Gender  Age  Occupation  \
# 0    1.0  0.000060    0.000439       0    0          10
# 1    1.0  0.000060    0.001078       0    0          10
# 2    1.0  0.000060    0.000191       0    0          10
# 3    1.0  0.000060    0.000633       0    0          10
# 4    1.0  0.000137    0.000361       1    6          16
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               0                   3
# 1                           2               0                   1
# 2                           2               0                  12
# 3                           2               0                  12
# 4                           4               0                   8
#
#    Product_Category_2  Product_Category_3  City_Category_B  City_Category_C
# 0                 0.0                 0.0                0                0
# 1                 6.0                14.0                0                0
# 2                 0.0                 0.0                0                0
# 3                14.0                 0.0                0                0
# 4                 0.0                 0.0                0                1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=3)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((440054, 13), (110014, 13), (440054,), (110014,))

# %%
model = sm.OLS(y_train,x_train).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Purchase   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     9139.
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):               0.00
# Time:                        23:04:00   Log-Likelihood:            -4.3255e+06
# No. Observations:              440054   AIC:                         8.651e+06
# Df Residuals:                  440041   BIC:                         8.651e+06
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       8556.8842     32.880    260.242      0.000    8492.440    8621.329
# User_ID                    -4.622e+05   2.56e+04    -18.057      0.000   -5.12e+05   -4.12e+05
# Product_ID                  1.692e+06    1.1e+04    153.368      0.000    1.67e+06    1.71e+06
# Gender                       479.7461     15.903     30.167      0.000     448.577     510.915
# Age                          128.6561      5.336     24.112      0.000     118.198     139.114
# Occupation                     4.5907      1.051      4.368      0.000       2.531       6.650
# Stay_In_Current_City_Years    13.2272      5.260      2.515      0.012       2.918      23.537
# Marital_Status               -36.6675     14.505     -2.528      0.011     -65.096      -8.239
# Product_Category_1          -309.8231      1.888   -164.123      0.000    -313.523    -306.123
# Product_Category_2            -2.1573      1.099     -1.963      0.050      -4.312      -0.003
# Product_Category_3           106.2691      1.201     88.484      0.000     103.915     108.623
# City_Category_B               33.1936     17.223      1.927      0.054      -0.563      66.950
# City_Category_C              141.2985     21.057      6.710      0.000     100.027     182.570
# ==============================================================================
# Omnibus:                    45210.857   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            63268.606
# Skew:                           0.819   Prob(JB):                         0.00
# Kurtosis:                       3.877   Cond. No.                     5.36e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.36e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
sns.distplot(model.resid)
plt.xlabel('Skew: %.2f Kurt: %.2f'%(model.resid.skew(),model.resid.kurt()))
# Out:
# Text(0.5, 0, 'Skew: 0.82 Kurt: 0.88')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = [variance_inflation_factor(x_train.values,i) for i in range(x_train.shape[1])]

# %%
pd.DataFrame({'VIF': vif[:]},index=x_train.columns).sort_values(by=['VIF'],ascending=False)
# Out:
#                                   VIF
# const                       23.553619
# City_Category_C              2.071263
# City_Category_B              1.574682
# User_ID                      1.448297
# Product_Category_3           1.229047
# Product_Category_1           1.205720
# Product_ID                   1.153860
# Age                          1.136892
# Marital_Status               1.108732
# Gender                       1.024818
# Occupation                   1.024282
# Product_Category_2           1.017176
# Stay_In_Current_City_Years   1.001953

# %% [markdown]
# ## Let us try some regularization methods

# %%
from sklearn.linear_model import Ridge,Lasso,ElasticNet
from sklearn.model_selection import GridSearchCV

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=3)

# %%
param = {'alpha':[0.01,0.1,1,10],
             'l1_ratio':[0,0.3,0.5,1]}

# %%
gscv = GridSearchCV(estimator=ElasticNet(),
                   param_grid=param,
                   scoring='r2',
                   verbose=3,
                   cv=3)

# %%
gscv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV 1/3] END ............alpha=0.01, l1_ratio=0;, score=0.151 total time=   6.2s
# [CV 2/3] END ............alpha=0.01, l1_ratio=0;, score=0.155 total time=   6.0s
# [CV 3/3] END ............alpha=0.01, l1_ratio=0;, score=0.152 total time=   6.3s
# [CV 1/3] END ..........alpha=0.01, l1_ratio=0.3;, score=0.151 total time=   0.1s
# [CV 2/3] END ..........alpha=0.01, l1_ratio=0.3;, score=0.155 total time=   0.1s
# [CV 3/3] END ..........alpha=0.01, l1_ratio=0.3;, score=0.152 total time=   0.1s
# [CV 1/3] END ..........alpha=0.01, l1_ratio=0.5;, score=0.151 total time=   0.1s
# [CV 2/3] END ..........alpha=0.01, l1_ratio=0.5;, score=0.155 total time=   0.1s
# [CV 3/3] END ..........alpha=0.01, l1_ratio=0.5;, score=0.152 total time=   0.1s
# [CV 1/3] END ............alpha=0.01, l1_ratio=1;, score=0.199 total time=   0.1s
# [CV 2/3] END ............alpha=0.01, l1_ratio=1;, score=0.202 total time=   0.1s
# [CV 3/3] END ............alpha=0.01, l1_ratio=1;, score=0.197 total time=   0.1s
# [CV 1/3] END .............alpha=0.1, l1_ratio=0;, score=0.151 total time=   6.3s
# [CV 2/3] END .............alpha=0.1, l1_ratio=0;, score=0.155 total time=   6.0s
# [CV 3/3] END .............alpha=0.1, l1_ratio=0;, score=0.152 total time=   6.1s
# [CV 1/3] END ...........alpha=0.1, l1_ratio=0.3;, score=0.151 total time=   0.0s
# [CV 2/3] END ...........alpha=0.1, l1_ratio=0.3;, score=0.155 total time=   0.1s
# [CV 3/3] END ...........alpha=0.1, l1_ratio=0.3;, score=0.152 total time=   0.1s
# [CV 1/3] END ...........alpha=0.1, l1_ratio=0.5;, score=0.151 total time=   0.0s
# [CV 2/3] END ...........alpha=0.1, l1_ratio=0.5;, score=0.155 total time=   0.1s
# [CV 3/3] END ...........alpha=0.1, l1_ratio=0.5;, score=0.152 total time=   0.0s
# [CV 1/3] END .............alpha=0.1, l1_ratio=1;, score=0.197 total time=   0.1s
# [CV 2/3] END .............alpha=0.1, l1_ratio=1;, score=0.201 total time=   0.1s
# [CV 3/3] END .............alpha=0.1, l1_ratio=1;, score=0.196 total time=   0.1s
# [CV 1/3] END ...............alpha=1, l1_ratio=0;, score=0.148 total time=   6.4s
# [CV 2/3] END ...............alpha=1, l1_ratio=0;, score=0.151 total time=   6.2s
# [CV 3/3] END ...............alpha=1, l1_ratio=0;, score=0.149 total time=   6.2s
# [CV 1/3] END .............alpha=1, l1_ratio=0.3;, score=0.149 total time=   0.0s
# [CV 2/3] END .............alpha=1, l1_ratio=0.3;, score=0.152 total time=   0.0s
# [CV 3/3] END .............alpha=1, l1_ratio=0.3;, score=0.150 total time=   0.0s
# [CV 1/3] END .............alpha=1, l1_ratio=0.5;, score=0.149 total time=   0.0s
# [CV 2/3] END .............alpha=1, l1_ratio=0.5;, score=0.153 total time=   0.0s
# [CV 3/3] END .............alpha=1, l1_ratio=0.5;, score=0.150 total time=   0.0s
# [CV 1/3] END ...............alpha=1, l1_ratio=1;, score=0.151 total time=   0.0s
# [CV 2/3] END ...............alpha=1, l1_ratio=1;, score=0.155 total time=   0.0s
# [CV 3/3] END ...............alpha=1, l1_ratio=1;, score=0.152 total time=   0.0s
# [CV 1/3] END ..............alpha=10, l1_ratio=0;, score=0.136 total time=   6.1s
# [CV 2/3] END ..............alpha=10, l1_ratio=0;, score=0.138 total time=   6.0s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 gscv.fit(x_train,y_train)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
#    1378     """Search all candidates in param_grid"""
# -> 1379     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:822, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     814 if self.verbose > 0:
#     815     print(
#     816         "Fitting {0} folds for each of {1} candidates,"
#     817         " totalling {2} fits".format(
#     818             n_splits, n_candidates, n_candidates * n_splits
#     819         )
#     820     )
# --> 822 out = parallel(
#     823     delayed(_fit_and_score)(
#     824         clone(base_estimator),
#     825         X,
#     826         y,
#     827         train=train,
#     828         test=test,
#     829         parameters=parameters,
#     830         split_progress=(split_idx, n_splits),
#     831         candidate_progress=(cand_idx, n_candidates),
#     832         **fit_and_score_kwargs,
#     833     )
#     834     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     835         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     836     )
#     837 )
#     839 if len(out) < 1:
#     840     raise ValueError(
#     841         "No fits were performed. "
#     842         "Was the CV iterator empty? "
#     843         "Were there no candidates?"
#     844     )
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\joblib\parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1054, in ElasticNet.fit(self, X, y, sample_weight, check_input)
#    1052 else:
#    1053     this_Xy = None
# -> 1054 _, this_coef, this_dual_gap, this_iter = self.path(
#    1055     X,
#    1056     y[:, k],
#    1057     l1_ratio=self.l1_ratio,
#    1058     eps=None,
#    1059     n_alphas=None,
#    1060     alphas=[alpha],
#    1061     precompute=precompute,
#    1062     Xy=this_Xy,
#    1063     copy_X=True,
#    1064     coef_init=coef_[k],
#    1065     verbose=False,
#    1066     return_n_iter=True,
#    1067     positive=self.positive,
#    1068     check_input=False,
#    1069     # from here on **params
#    1070     tol=self.tol,
#    1071     X_offset=X_offset,
#    1072     X_scale=X_scale,
#    1073     max_iter=self.max_iter,
#    1074     random_state=self.random_state,
#    1075     selection=self.selection,
#    1076     sample_weight=sample_weight,
#    1077 )
#    1078 coef_[k] = this_coef[:, 0]
#    1079 dual_gaps_[k] = this_dual_gap[0]
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     634     model = cd_fast.enet_coordinate_descent_gram(
#     635         coef_,
#     636         l1_reg,
#    (...)
#     645         positive,
#     646     )
#     647 elif precompute is False:
# --> 648     model = cd_fast.enet_coordinate_descent(
#     649         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     650     )
#     651 else:
#     652     raise ValueError(
#     653         "Precompute should be one of True, False, 'auto' or array-like. Got %r"
#     654         % precompute
#     655     )
#
# File sklearn\linear_model\_cd_fast.pyx:251, in sklearn.linear_model._cd_fast.enet_coordinate_descent()
#
# File ~\anaconda3\lib\site-packages\numpy\core\getlimits.py:383, in finfo.__new__(cls, dtype)
#     382 def __new__(cls, dtype):
# --> 383     try:
#     384         dtype = numeric.dtype(dtype)
#     385     except TypeError:
#     386         # In case a float instance was given
#
# KeyboardInterrupt:

# %%
gscv.best_score_

# %%
gscv.best_params_

# %% [markdown]
# ## Let us try Models with other algorithms

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

from sklearn.metrics import r2_score,mean_squared_error

# %%
def model_results(model,x_train,y_train,x_test,y_test):
    print(str(model))
    n = x_train.shape[0]
    p = x_train.shape[1]
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    r2 = r2_score(y_test,y_pred)
    adj_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    print('R2 :\t',r2)
    print('Adj R2:\t',adj_r2)
    print('MSE:\t',mean_squared_error(y_test,y_pred))
    print('RMSE:\t',(mean_squared_error(y_test,y_pred))**0.5,'\n')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
#x_train_s = sc.fit_transform(x_train)
#x_test_s = sc.transform(x_test)


model_results(KNeighborsRegressor(n_neighbors=7),x_train,y_train,x_test,y_test)
# Out:
# KNeighborsRegressor(n_neighbors=7)
# R2 :	 0.6259188043167325
# Adj R2:	 0.6259086030528771
# MSE:	 9437118.96339427
# RMSE:	 3071.989414596715

# %%
param = {'n_neighbors':[5,7,9,12]}

# %%
gscv = GridSearchCV(estimator=KNeighborsRegressor(),
                   param_grid=param,
                   scoring='r2',
                   verbose=3,
                   cv=3)

# %%
gscv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV 1/3] END .....................n_neighbors=5;, score=0.602 total time=  21.0s
# [CV 2/3] END .....................n_neighbors=5;, score=0.606 total time=  20.9s
# [CV 3/3] END .....................n_neighbors=5;, score=0.602 total time=  20.8s
# [CV 1/3] END .....................n_neighbors=7;, score=0.611 total time=  22.7s
# [CV 2/3] END .....................n_neighbors=7;, score=0.614 total time=  22.7s
# [CV 3/3] END .....................n_neighbors=7;, score=0.611 total time=  22.6s
# [CV 1/3] END .....................n_neighbors=9;, score=0.614 total time=  24.3s
# [CV 2/3] END .....................n_neighbors=9;, score=0.616 total time=  24.6s
# [CV 3/3] END .....................n_neighbors=9;, score=0.614 total time=  24.7s
# [CV 1/3] END ....................n_neighbors=12;, score=0.613 total time=  26.7s
# [CV 2/3] END ....................n_neighbors=12;, score=0.615 total time=  26.4s
# [CV 3/3] END ....................n_neighbors=12;, score=0.613 total time=  26.2s
# GridSearchCV(cv=3, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [5, 7, 9, 12]}, scoring='r2',
#              verbose=3)

# %%
gscv.best_params_
# Out:
# {'n_neighbors': 9}

# %%
gscv.best_score_
# Out:
# 0.6143029894563694

# %%
model_results(DecisionTreeRegressor(max_depth=7),x_train,y_train,x_test,y_test)
# Out:
# DecisionTreeRegressor(max_depth=7)
# R2 :	 0.6853137391388707
# Adj R2:	 0.6853051575859466
# MSE:	 7938735.531648202
# RMSE:	 2817.576180274138

# %%
param = {'max_depth':[8,9,10,11,12]}

# %%
gscv = GridSearchCV(estimator=DecisionTreeRegressor(),
                   param_grid=param,
                   scoring='r2',
                   verbose=3,
                   cv=3)

# %%
gscv.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV 1/3] END .......................max_depth=8;, score=0.689 total time=   0.6s
# [CV 2/3] END .......................max_depth=8;, score=0.691 total time=   0.6s
# [CV 3/3] END .......................max_depth=8;, score=0.682 total time=   0.6s
# [CV 1/3] END .......................max_depth=9;, score=0.692 total time=   0.7s
# [CV 2/3] END .......................max_depth=9;, score=0.694 total time=   0.7s
# [CV 3/3] END .......................max_depth=9;, score=0.685 total time=   0.7s
# [CV 1/3] END ......................max_depth=10;, score=0.694 total time=   0.8s
# [CV 2/3] END ......................max_depth=10;, score=0.696 total time=   0.8s
# [CV 3/3] END ......................max_depth=10;, score=0.687 total time=   0.8s
# [CV 1/3] END ......................max_depth=11;, score=0.693 total time=   0.8s
# [CV 2/3] END ......................max_depth=11;, score=0.695 total time=   0.9s
# [CV 3/3] END ......................max_depth=11;, score=0.687 total time=   0.8s
# [CV 1/3] END ......................max_depth=12;, score=0.690 total time=   0.9s
# [CV 2/3] END ......................max_depth=12;, score=0.692 total time=   0.9s
# [CV 3/3] END ......................max_depth=12;, score=0.685 total time=   0.9s
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [8, 9, 10, 11, 12]}, scoring='r2',
#              verbose=3)

# %%
gscv.best_params_
# Out:
# {'max_depth': 10}

# %%
gscv.best_score_
# Out:
# 0.6922694904002431

# %%
model_results(DecisionTreeRegressor(**gscv.best_params_),x_train,y_train,x_test,y_test)
# Out:
# DecisionTreeRegressor(max_depth=10)
# R2 :	 0.6953658088851017
# Adj R2:	 0.695357501453991
# MSE:	 7685147.329091669
# RMSE:	 2772.2098277532436

# %%
model_results(RandomForestRegressor(n_estimators=200,max_depth=9),x_train,y_train,x_test,y_test)
# Out:
# RandomForestRegressor(max_depth=9, n_estimators=200)
# R2 :	 0.6976526904788645
# Adj R2:	 0.6976444454114407
# MSE:	 7627455.111721274
# RMSE:	 2761.7847692608625

# %%
params = {'n_estimators':[200,250,300],
         'max_depth':[8,9,10]}

gscv = GridSearchCV(estimator=RandomForestRegressor(),
                   param_grid=params,
                   cv=3,
                   scoring='r2',
                   verbose=3)

# %%
# gscv.fit(x_train,y_train)

# %%
# Saving a model using pickle file

# %%
model_dt = DecisionTreeRegressor(max_depth=9)

# %%
model_dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=9)

# %%
model_dt.score(x_test,y_test)
# Out:
# 0.6924922462487552

# %%
import pickle

# %%
file = open('dt_model.pkl','wb')
pickle.dump(model_dt,file)

# %%
file = open('dt_model.pkl','rb')
mod = pickle.load(file)

# %%
mod.score(x_test,y_test)
# Out:
# 0.6924922462487552

# %%
## Gradient Boosting

# %%
model_results(GradientBoostingRegressor(n_estimators=150,max_depth=9),x_train,y_train,x_test,y_test)
# Out:
# GradientBoostingRegressor(max_depth=9, n_estimators=150)
# R2 :	 0.7387568614808488
# Adj R2:	 0.7387497373318213
# MSE:	 6590501.220123191
# RMSE:	 2567.197152562146

# %%
## Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor

# %%
bag_reg = BaggingRegressor(base_estimator=KNeighborsRegressor(n_neighbors=7),
                          n_estimators=100)

# %%
bag_reg.fit(x_train,y_train)
# Out:
# BaggingRegressor(base_estimator=KNeighborsRegressor(n_neighbors=7),
#                  n_estimators=100)

# %%
# bag_reg.score(x_test,y_test)

# %%
# Stacking
import pickle

# %%
from sklearn.ensemble import StackingRegressor

# %%
base_models = [('DT',DecisionTreeRegressor(max_depth=10)),
              ('RF',RandomForestRegressor(n_estimators=200,max_depth=10)),
              ('GBR',GradientBoostingRegressor(n_estimators=200,max_depth=10))]

# %%
stack_model = StackingRegressor(estimators=base_models,cv=3)

# %%
stack_model.fit(x_train,y_train)
# Out:
# StackingRegressor(cv=3,
#                   estimators=[('DT', DecisionTreeRegressor(max_depth=10)),
#                               ('RF',
#                                RandomForestRegressor(max_depth=10,
#                                                      n_estimators=200)),
#                               ('GBR',
#                                GradientBoostingRegressor(max_depth=10,
#                                                          n_estimators=200))])

# %%
file = open('stacking.pkl','wb')
stack_model_pik = pickle.dump(stack_model,file)

# %%
file = open('stacking.pkl','rb')
mod = pickle.load(file)

# %%
mod.score(x_test,y_test)
# Out:
# 0.6135673196620226

# %%
# catboost

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.0.6-cp39-none-win_amd64.whl (73.9 MB)
# Requirement already satisfied: scipy in c:\users\gaurav siwal\anaconda3\lib\site-packages (from catboost) (1.7.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from catboost) (1.21.5)
# Requirement already satisfied: graphviz in c:\users\gaurav siwal\appdata\roaming\python\python39\site-packages (from catboost) (0.20.1)
# Requirement already satisfied: six in c:\users\gaurav siwal\anaconda3\lib\site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\gaurav siwal\anaconda3\lib\site-packages (from catboost) (3.5.1)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from catboost) (1.4.2)
# Requirement already satisfied: plotly in c:\users\gaurav siwal\anaconda3\lib\site-packages (from catboost) (5.6.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from pandas>=0.24.0->catboost) (2021.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from matplotlib->catboost) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from matplotlib->catboost) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from plotly->catboost) (8.0.1)
# Installing collected packages: catboost
# Successfully installed catboost-1.0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from catboost import CatBoostRegressor

# %%
model_cat = CatBoostRegressor(n_estimators=600,max_depth=9)

# %%
model_cat.fit(x_train,y_train)
# Out:
# Learning rate set to 0.162262
# 0:	learn: 4530.6232056	total: 103ms	remaining: 1m 1s
# 1:	learn: 4142.2427249	total: 152ms	remaining: 45.3s
# 2:	learn: 3845.8547329	total: 210ms	remaining: 41.7s
# 3:	learn: 3607.4014324	total: 259ms	remaining: 38.6s
# 4:	learn: 3443.3625722	total: 308ms	remaining: 36.6s
# 5:	learn: 3315.3896175	total: 355ms	remaining: 35.1s
# 6:	learn: 3205.9216927	total: 402ms	remaining: 34s
# 7:	learn: 3124.1970670	total: 458ms	remaining: 33.9s
# 8:	learn: 3063.7422470	total: 508ms	remaining: 33.4s
# 9:	learn: 3014.6048098	total: 555ms	remaining: 32.8s
# 10:	learn: 2977.9313070	total: 612ms	remaining: 32.8s
# 11:	learn: 2953.2053203	total: 666ms	remaining: 32.6s
# 12:	learn: 2932.3912213	total: 718ms	remaining: 32.4s
# 13:	learn: 2914.8027516	total: 769ms	remaining: 32.2s
# 14:	learn: 2898.8313271	total: 816ms	remaining: 31.8s
# 15:	learn: 2885.8110945	total: 874ms	remaining: 31.9s
# 16:	learn: 2874.4288669	total: 939ms	remaining: 32.2s
# 17:	learn: 2866.4075304	total: 989ms	remaining: 32s
# 18:	learn: 2859.2515097	total: 1.04s	remaining: 31.8s
# 19:	learn: 2853.1431911	total: 1.09s	remaining: 31.6s
# 20:	learn: 2846.3240353	total: 1.13s	remaining: 31.2s
# 21:	learn: 2842.2367882	total: 1.19s	remaining: 31.2s
# 22:	learn: 2838.2841714	total: 1.23s	remaining: 30.9s
# 23:	learn: 2834.1077482	total: 1.28s	remaining: 30.7s
# 24:	learn: 2830.5310766	total: 1.32s	remaining: 30.5s
# 25:	learn: 2827.5872743	total: 1.37s	remaining: 30.2s
# 26:	learn: 2823.2510067	total: 1.42s	remaining: 30.2s
# 27:	learn: 2819.2063012	total: 1.47s	remaining: 30s
# 587:	learn: 2473.9427588	total: 30.8s	remaining: 629ms
# 588:	learn: 2473.6881521	total: 30.9s	remaining: 577ms
# 589:	learn: 2473.4506471	total: 30.9s	remaining: 524ms
# 590:	learn: 2473.0744290	total: 31s	remaining: 472ms
# 591:	learn: 2472.8051926	total: 31s	remaining: 420ms
# 592:	learn: 2472.5734211	total: 31.1s	remaining: 367ms
# 593:	learn: 2472.4060505	total: 31.1s	remaining: 315ms
# 594:	learn: 2472.1465472	total: 31.2s	remaining: 262ms
# 595:	learn: 2471.9374388	total: 31.3s	remaining: 210ms
# 596:	learn: 2471.7705325	total: 31.3s	remaining: 157ms
# 597:	learn: 2471.2812800	total: 31.4s	remaining: 105ms
# 598:	learn: 2471.1389348	total: 31.4s	remaining: 52.5ms
# 599:	learn: 2471.0493531	total: 31.5s	remaining: 0us

# %%
model_cat.score(x_test,y_test)
# Out:
# 0.7419227053842676

# %%
# XGBOOST

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.6.2-py3-none-win_amd64.whl (125.4 MB)
# Requirement already satisfied: scipy in c:\users\gaurav siwal\anaconda3\lib\site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in c:\users\gaurav siwal\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBRegressor

# %%
model_xg = XGBRegressor(n_estimators=400, max_depth=7)

# %%
model_xg.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=400, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
model_xg.score(x_test,y_test)
# Out:
# 0.7485608522793818

# %%
# Light GBM

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: scipy in c:\users\gaurav siwal\anaconda3\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from lightgbm) (1.1.2)
# Requirement already satisfied: numpy in c:\users\gaurav siwal\anaconda3\lib\site-packages (from lightgbm) (1.21.5)
# Requirement already satisfied: wheel in c:\users\gaurav siwal\anaconda3\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\gaurav siwal\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from lightgbm import LGBMRegressor

# %%
model_lgb = LGBMRegressor(n_estimators=400, max_depth=9)

# %%
model_lgb.fit(x_train,y_train)
# Out:
# LGBMRegressor(max_depth=9, n_estimators=400)

# %%
model_lgb.score(x_test,y_test)
# Out:
# 0.7283432399127798

# %%
## Submissions

# %%
test_f
# Out:
#          User_ID  Product_ID  Gender  Age  Occupation  \
# 0       0.000019    0.001701       1    4           7
# 1       0.000108    0.000473       1    2          17
# 2       0.000413    0.000277       0    3           1
# 3       0.000413    0.000029       0    3           1
# 4       0.000140    0.000997       0    2           1
# ...          ...         ...     ...  ...         ...
# 233594  0.000917    0.000288       0    2          15
# 233595  0.000917    0.000274       0    2          15
# 233596  0.000917    0.000343       0    2          15
# 233597  0.000208    0.000366       0    4           1
# 233598  0.000131    0.000744       0    4           0
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                                2               1                   1
# 1                                0               0                   3
# 2                                4               1                   5
# 3                                4               1                   4
# 4                                1               0                   4
# ...                            ...             ...                 ...
# 233594                           4               1                   8
# 233595                           4               1                   5
# 233596                           4               1                   1
# 233597                           4               0                  10
# 233598                           4               1                   4
#
#         Product_Category_2  Product_Category_3  City_Category_B  \
# 0                     11.0                 0.0                1
# 1                      5.0                 0.0                0
# 2                     14.0                 0.0                1
# 3                      9.0                 0.0                1
# 4                      5.0                12.0                0
# ...                    ...                 ...              ...
# 233594                 0.0                 0.0                1
# 233595                 8.0                 0.0                1
# 233596                 5.0                12.0                1
# 233597                16.0                 0.0                0
# 233598                 5.0                 0.0                1
#
#         City_Category_C
# 0                     0
# 1                     1
# 2                     0
# 3                     0
# 4                     1
# ...                 ...
# 233594                0
# 233595                0
# 233596                0
# 233597                1
# 233598                0
#
# [233599 rows x 12 columns]

# %%
y_pred_test_f = model_xg.predict(test_f)

# %%
y_test_f = pd.DataFrame(y_pred_test_f)

# %%
y_test_f.to_csv('Answer.csv')
